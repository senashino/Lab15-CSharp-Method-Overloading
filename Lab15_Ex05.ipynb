// %% [markdown]
// # Lab 15 Exercise 5

// %% [markdown]
// ## Virtual member inheritance

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab15_Ex05
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// Derived_2 d2 = new Derived_2();
// Base b = (Base) d2;
// Derived_1 d1 = (Derived_1) d2;
//
//
// b.A();
// d1.A();
// d2.A();
//
// class Base
// {
//     public virtual void A()
//     {
//         System.Console.WriteLine("Base.A()");
//     }
// }
// class Derived_1 : Base
// {
//     public override void A()
//     {
//         System.Console.WriteLine("Derived_1.A()");
//     }
// }
// class Derived_2 : Derived_1
// {
//     public override void A()
//     {
//         System.Console.WriteLine("Derived_2.A()");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab15_Ex05
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
// ```cmd
// dotnet run --project Lab15_Ex05
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ในการทดลองนี้มีการใช้ type casting เพื่อแปลงอ็อบเจกต์จากคลาสย่อย (Derived_2) เป็นคลาสหลัก (Base) และคลาสลูกระหว่างกลาง (Derived_1) ผ่านการแปลงชนิดของตัวแปร (casting) เพื่อทดสอบว่าเมธอด A() ในแต่ละคลาสทำงานอย่างไร
